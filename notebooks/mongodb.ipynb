# %%
import pandas as pd

# %%
df=pd.read_csv("DNS-testing.csv")

# %%
from pymongo import MongoClient

# Paste your connection string
conn_str ="mongodb+srv://polojisanjasai:ramakrishna9063898392@cluster0.melms.mongodb.net/?retryWrites=true&w=majority"

# Connect
client = MongoClient(conn_str)

# Select database
db = client['Ddos_main']

# Select collection
collection = db['DdosData']

# %%
data_dict = df.to_dict("records")  # each row becomes a dictionary

# %%
# Insert all rows at once
collection.insert_many(data_dict)

print("Data pushed to MongoDB successfully!")
# Out:
# Data pushed to MongoDB successfully!
